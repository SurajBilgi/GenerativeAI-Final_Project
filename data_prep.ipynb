# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_core.utils.json import parse_json_markdown
import pandas as pd

# %%
llm = ChatOpenAI(model="gpt-4-1106-preview")

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a restaurant chatbot and have detailed information regarding restaurants and their menu"),
    ("user", "{input}")
])

# %%
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
query = """
Generate data for 3 random restaurants. The data must contain the following:
1. Restaurant Name
2. Each Restaurant must have a menu with 3 type of dishes: Starters, Main Course and Desserts each having 5 items
3. The Starters and Main Course must have a mix of veg and non veg items
4. The non veg items should be related to chicken, beef, mutton and fish
5. Each item must be specified as veg and non-veg
6. Each dish must have a short description, ingredients, cost and preparation time
7. Output the data in JSON format
"""

# %%
output = chain.invoke({"input": query})
output
# Out:
# 'Below are the generated data for three random restaurants, formatted in JSON:\n\n```json\n[\n  {\n    "RestaurantName": "The Culinary Haven",\n    "Menu": {\n      "Starters": [\n        {\n          "Name": "Golden Corn Soup",\n          "Description": "A creamy, comforting blend of sweet corn and herbs.",\n          "Ingredients": ["Sweet corn", "Vegetable stock", "Cream", "Herbs"],\n          "Cost": "$5.99",\n          "PreparationTime": "10 minutes"\n        },\n        {\n          "Name": "Chicken Satay Skewers",\n          "Description": "Grilled chicken skewers marinated in a blend of spices and served with peanut sauce.",\n          "Ingredients": ["Chicken", "Soy sauce", "Peanut sauce", "Spices"],\n          "Cost": "$7.99",\n          "PreparationTime": "15 minutes"\n        },\n        {\n          "Name": "Beef Carpaccio",\n          "Description": "Thinly sliced raw beef dressed with olive oil, lemon juice, and capers.",\n          "Ingredients": ["Beef", "Olive oil", "Lemon juice", "Capers"],\n          "Cost": "$9.99",\n          "PreparationTime": "10 minutes"\n        },\n        {\n          "Name": "Crispy Calamari Rings",\n          "Description": "Fried calamari rings served with a tangy marinara sauce.",\n          "Ingredients": ["Calamari", "Flour", "Marinara sauce", "Lemon"],\n          "Cost": "$8.50",\n          "PreparationTime": "12 minutes"\n        },\n        {\n          "Name": "Veggie Spring Rolls",\n          "Description": "Crispy rolls filled with fresh vegetables and glass noodles.",\n          "Ingredients": ["Cabbage", "Carrot", "Glass noodles", "Spring roll wrappers"],\n          "Cost": "$6.50",\n          "PreparationTime": "15 minutes"\n        }\n      ],\n      "Main Course": [\n        {\n          "Name": "Mutton Rogan Josh",\n          "Description": "A classic Kashmiri dish with tender mutton pieces in a rich aromatic gravy.",\n          "Ingredients": ["Mutton", "Yogurt", "Spices", "Tomato puree"],\n          "Cost": "$15.99",\n          "PreparationTime": "30 minutes"\n        },\n        {\n          "Name": "Grilled Salmon with Dill Sauce",\n          "Description": "Fresh salmon fillets grilled to perfection, topped with a creamy dill sauce.",\n          "Ingredients": ["Salmon", "Dill", "Lemon", "Cream"],\n          "Cost": "$17.99",\n          "PreparationTime": "25 minutes"\n        },\n        {\n          "Name": "Beef Steak with Peppercorn Sauce",\n          "Description": "Juicy beef steak cooked to your preference and topped with a rich peppercorn sauce.",\n          "Ingredients": ["Beef steak", "Peppercorns", "Cream", "Butter"],\n          "Cost": "$19.99",\n          "PreparationTime": "20 minutes"\n        },\n        {\n          "Name": "Vegetable Lasagna",\n          "Description": "Layers of pasta, rich tomato sauce, and roasted vegetables topped with melted cheese.",\n          "Ingredients": ["Pasta sheets", "Tomato sauce", "Mixed vegetables", "Cheese"],\n          "Cost": "$12.99",\n          "PreparationTime": "35 minutes"\n        },\n        {\n          "Name": "Butter Chicken",\n          "Description": "Tender chicken pieces in a creamy tomato gravy, seasoned with Indian spices.",\n          "Ingredients": ["Chicken", "Tomato puree", "Cream", "Indian spices"],\n          "Cost": "$14.99",\n          "PreparationTime": "25 minutes"\n        }\n      ],\n      "Desserts": [\n        {\n          "Name": "Chocolate Lava Cake",\n          "Description": "A warm, gooey chocolate cake with a molten center, served with vanilla ice cream.",\n          "Ingredients": ["Chocolate", "Flour", "Eggs", "Sugar"],\n          "Cost": "$6.99",\n          "PreparationTime": "20 minutes"\n        },\n        {\n          "Name": "New York Cheesecake",\n          "Description": "Creamy cheesecake with a graham cracker crust and a fruity berry compote.",\n          "Ingredients": ["Cream cheese", "Graham crackers", "Eggs", "Berry compote"],\n          "Cost": "$7.50 ...

# %%
restaurant_details = parse_json_markdown(output)

# %%
len(restaurant_details)
# Out:
# 3

# %%
for i in range(len(restaurant_details)):
    print(restaurant_details[i]["RestaurantName"])
# Out:
# The Culinary Haven
# Bistro Fusion
# Spice Symphony

# %%
restaurant_details[0]["Menu"]
# Out:
# {'Starters': [{'Name': 'Golden Corn Soup',
#    'Description': 'A creamy, comforting blend of sweet corn and herbs.',
#    'Ingredients': ['Sweet corn', 'Vegetable stock', 'Cream', 'Herbs'],
#    'Cost': '$5.99',
#    'PreparationTime': '10 minutes'},
#   {'Name': 'Chicken Satay Skewers',
#    'Description': 'Grilled chicken skewers marinated in a blend of spices and served with peanut sauce.',
#    'Ingredients': ['Chicken', 'Soy sauce', 'Peanut sauce', 'Spices'],
#    'Cost': '$7.99',
#    'PreparationTime': '15 minutes'},
#   {'Name': 'Beef Carpaccio',
#    'Description': 'Thinly sliced raw beef dressed with olive oil, lemon juice, and capers.',
#    'Ingredients': ['Beef', 'Olive oil', 'Lemon juice', 'Capers'],
#    'Cost': '$9.99',
#    'PreparationTime': '10 minutes'},
#   {'Name': 'Crispy Calamari Rings',
#    'Description': 'Fried calamari rings served with a tangy marinara sauce.',
#    'Ingredients': ['Calamari', 'Flour', 'Marinara sauce', 'Lemon'],
#    'Cost': '$8.50',
#    'PreparationTime': '12 minutes'},
#   {'Name': 'Veggie Spring Rolls',
#    'Description': 'Crispy rolls filled with fresh vegetables and glass noodles.',
#    'Ingredients': ['Cabbage',
#     'Carrot',
#     'Glass noodles',
#     'Spring roll wrappers'],
#    'Cost': '$6.50',
#    'PreparationTime': '15 minutes'}],
#  'Main Course': [{'Name': 'Mutton Rogan Josh',
#    'Description': 'A classic Kashmiri dish with tender mutton pieces in a rich aromatic gravy.',
#    'Ingredients': ['Mutton', 'Yogurt', 'Spices', 'Tomato puree'],
#    'Cost': '$15.99',
#    'PreparationTime': '30 minutes'},
#   {'Name': 'Grilled Salmon with Dill Sauce',
#    'Description': 'Fresh salmon fillets grilled to perfection, topped with a creamy dill sauce.',
#    'Ingredients': ['Salmon', 'Dill', 'Lemon', 'Cream'],
#    'Cost': '$17.99',
#    'PreparationTime': '25 minutes'},
#   {'Name': 'Beef Steak with Peppercorn Sauce',
#    'Description': 'Juicy beef steak cooked to your preference and topped with a rich peppercorn sauce.',
#    'Ingredients': ['Beef steak', 'Peppercorns', 'Cream', 'Butter'],
#    'Cost': '$19.99',
#    'PreparationTime': '20 minutes'},
#   {'Name': 'Vegetable Lasagna',
#    'Description': 'Layers of pasta, rich tomato sauce, and roasted vegetables topped with melted cheese.',
#    'Ingredients': ['Pasta sheets',
#     'Tomato sauce',
#     'Mixed vegetables',
#     'Cheese'],
#    'Cost': '$12.99',
#    'PreparationTime': '35 minutes'},
#   {'Name': 'Butter Chicken',
#    'Description': 'Tender chicken pieces in a creamy tomato gravy, seasoned with Indian spices.',
#    'Ingredients': ['Chicken', 'Tomato puree', 'Cream', 'Indian spices'],
#    'Cost': '$14.99',
#    'PreparationTime': '25 minutes'}],
#  'Desserts': [{'Name': 'Chocolate Lava Cake',
#    'Description': 'A warm, gooey chocolate cake with a molten center, served with vanilla ice cream.',
#    'Ingredients': ['Chocolate', 'Flour', 'Eggs', 'Sugar'],
#    'Cost': '$6.99',
#    'PreparationTime': '20 minutes'},
#   {'Name': 'New York Cheesecake',
#    'Description': 'Creamy cheesecake with a graham cracker crust and a fruity berry compote.',
#    'Ingredients': ['Cream cheese', 'Graham crackers', 'Eggs', 'Berry compote'],
#    'Cost': '$7.50',
#    'PreparationTime': '60 minutes'},
#   {'Name': 'Tiramisu',
#    'Description': 'A classic Italian no-bake dessert with layers of coffee-soaked ladyfingers and mascarpone cream.',
#    'Ingredients': ['Ladyfingers',
#     'Coffee',
#     'Mascarpone cheese',
#     'Cocoa powder'],
#    'Cost': '$7.99',
#    'PreparationTime': '30 minutes'},
#   {'Name': 'Apple Pie a la Mode',
#    'Description': 'Traditional apple pie served warm with a scoop of vanilla ice cream.',
#    'Ingredients': ['Apples', 'Pie crust', 'Cinnamon', 'Vanilla ice cream'],
#    'Cost': '$5.99',
#    'PreparationTime': '45 minutes'},
#   {'Name': 'Lemon Sorbet',
#    'Description': 'A refreshing and tangy frozen dessert made with fresh lemons.',
#    'Ingredients': ['Lemons', 'Sugar', 'Water'],
#    'Cost': '$4.99',
#    'PreparationTime': '180 minutes'}]}

# %%
restaurant_details[0]["Menu"].keys()
# Out:
# dict_keys(['Starters', 'Main Course', 'Desserts'])

# %%
restaurant_details[0]["Menu"]["Starters"]
# Out:
# [{'Name': 'Golden Corn Soup',
#   'Description': 'A creamy, comforting blend of sweet corn and herbs.',
#   'Ingredients': ['Sweet corn', 'Vegetable stock', 'Cream', 'Herbs'],
#   'Cost': '$5.99',
#   'PreparationTime': '10 minutes'},
#  {'Name': 'Chicken Satay Skewers',
#   'Description': 'Grilled chicken skewers marinated in a blend of spices and served with peanut sauce.',
#   'Ingredients': ['Chicken', 'Soy sauce', 'Peanut sauce', 'Spices'],
#   'Cost': '$7.99',
#   'PreparationTime': '15 minutes'},
#  {'Name': 'Beef Carpaccio',
#   'Description': 'Thinly sliced raw beef dressed with olive oil, lemon juice, and capers.',
#   'Ingredients': ['Beef', 'Olive oil', 'Lemon juice', 'Capers'],
#   'Cost': '$9.99',
#   'PreparationTime': '10 minutes'},
#  {'Name': 'Crispy Calamari Rings',
#   'Description': 'Fried calamari rings served with a tangy marinara sauce.',
#   'Ingredients': ['Calamari', 'Flour', 'Marinara sauce', 'Lemon'],
#   'Cost': '$8.50',
#   'PreparationTime': '12 minutes'},
#  {'Name': 'Veggie Spring Rolls',
#   'Description': 'Crispy rolls filled with fresh vegetables and glass noodles.',
#   'Ingredients': ['Cabbage',
#    'Carrot',
#    'Glass noodles',
#    'Spring roll wrappers'],
#   'Cost': '$6.50',
#   'PreparationTime': '15 minutes'}]

# %%
details = []
for restaurant in restaurant_details:
    for item_type in restaurant["Menu"]:
        for item in restaurant["Menu"][item_type]:
            out = {}
            out["restaurantname"] = restaurant["RestaurantName"]
            out["item_type"] = item_type
            out["item_name"] = item["Name"]
            out["descriptiom"] = item["Description"]
            out["ingredients"] = item["Ingredients"]
            out["cost"] = item["Cost"]
            out["preparation_time"] = item["PreparationTime"]
            details.append(out)

# %%
details
# Out:
# [{'restaurantname': 'The Culinary Haven',
#   'item_type': 'Starters',
#   'item_name': 'Golden Corn Soup',
#   'descriptiom': 'A creamy, comforting blend of sweet corn and herbs.',
#   'ingredients': ['Sweet corn', 'Vegetable stock', 'Cream', 'Herbs'],
#   'cost': '$5.99',
#   'preparation_time': '10 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Starters',
#   'item_name': 'Chicken Satay Skewers',
#   'descriptiom': 'Grilled chicken skewers marinated in a blend of spices and served with peanut sauce.',
#   'ingredients': ['Chicken', 'Soy sauce', 'Peanut sauce', 'Spices'],
#   'cost': '$7.99',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Starters',
#   'item_name': 'Beef Carpaccio',
#   'descriptiom': 'Thinly sliced raw beef dressed with olive oil, lemon juice, and capers.',
#   'ingredients': ['Beef', 'Olive oil', 'Lemon juice', 'Capers'],
#   'cost': '$9.99',
#   'preparation_time': '10 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Starters',
#   'item_name': 'Crispy Calamari Rings',
#   'descriptiom': 'Fried calamari rings served with a tangy marinara sauce.',
#   'ingredients': ['Calamari', 'Flour', 'Marinara sauce', 'Lemon'],
#   'cost': '$8.50',
#   'preparation_time': '12 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Starters',
#   'item_name': 'Veggie Spring Rolls',
#   'descriptiom': 'Crispy rolls filled with fresh vegetables and glass noodles.',
#   'ingredients': ['Cabbage',
#    'Carrot',
#    'Glass noodles',
#    'Spring roll wrappers'],
#   'cost': '$6.50',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Main Course',
#   'item_name': 'Mutton Rogan Josh',
#   'descriptiom': 'A classic Kashmiri dish with tender mutton pieces in a rich aromatic gravy.',
#   'ingredients': ['Mutton', 'Yogurt', 'Spices', 'Tomato puree'],
#   'cost': '$15.99',
#   'preparation_time': '30 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Main Course',
#   'item_name': 'Grilled Salmon with Dill Sauce',
#   'descriptiom': 'Fresh salmon fillets grilled to perfection, topped with a creamy dill sauce.',
#   'ingredients': ['Salmon', 'Dill', 'Lemon', 'Cream'],
#   'cost': '$17.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Main Course',
#   'item_name': 'Beef Steak with Peppercorn Sauce',
#   'descriptiom': 'Juicy beef steak cooked to your preference and topped with a rich peppercorn sauce.',
#   'ingredients': ['Beef steak', 'Peppercorns', 'Cream', 'Butter'],
#   'cost': '$19.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Main Course',
#   'item_name': 'Vegetable Lasagna',
#   'descriptiom': 'Layers of pasta, rich tomato sauce, and roasted vegetables topped with melted cheese.',
#   'ingredients': ['Pasta sheets',
#    'Tomato sauce',
#    'Mixed vegetables',
#    'Cheese'],
#   'cost': '$12.99',
#   'preparation_time': '35 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Main Course',
#   'item_name': 'Butter Chicken',
#   'descriptiom': 'Tender chicken pieces in a creamy tomato gravy, seasoned with Indian spices.',
#   'ingredients': ['Chicken', 'Tomato puree', 'Cream', 'Indian spices'],
#   'cost': '$14.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Desserts',
#   'item_name': 'Chocolate Lava Cake',
#   'descriptiom': 'A warm, gooey chocolate cake with a molten center, served with vanilla ice cream.',
#   'ingredients': ['Chocolate', 'Flour', 'Eggs', 'Sugar'],
#   'cost': '$6.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Desserts',
#   'item_name': 'New York Cheesecake',
#   'descriptiom': 'Creamy cheesecake with a graham cracker crust and a fruity berry compote.',
#   'ingredients': ['Cream cheese', 'Graham crackers', 'Eggs', 'Berry compote'],
#   'cost': '$7.50',
#   'preparation_time': '60 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Desserts',
#   'item_name': 'Tiramisu',
#   'descriptiom': 'A classic Italian no-bake dessert with layers of coffee-soaked ladyfingers and mascarpone cream.',
#   'ingredients': ['Ladyfingers',
#    'Coffee',
#    'Mascarpone cheese',
#    'Cocoa powder'],
#   'cost': '$7.99',
#   'preparation_time': '30 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Desserts',
#   'item_name': 'Apple Pie a la Mode',
#   'descriptiom': 'Traditional apple pie served warm with a scoop of vanilla ice cream.',
#   'ingredients': ['Apples', 'Pie crust', 'Cinnamon', 'Vanilla ice cream'],
#   'cost': '$5.99',
#   'preparation_time': '45 minutes'},
#  {'restaurantname': 'The Culinary Haven',
#   'item_type': 'Desserts',
#   'item_name': 'Lemon Sorbet',
#   'descriptiom': 'A refreshing and tangy frozen dessert made with fresh lemons.',
#   'ingredients': ['Lemons', 'Sugar', 'Water'],
#   'cost': '$4.99',
#   'preparation_time': '180 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Starters',
#   'item_name': 'Shrimp Cocktail',
#   'descriptiom': 'Chilled shrimp served with a zesty cocktail sauce.',
#   'ingredients': ['Shrimp', 'Cocktail sauce', 'Lemon'],
#   'cost': '$8.99',
#   'preparation_time': '10 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Starters',
#   'item_name': 'Bruschetta al Pomodoro',
#   'descriptiom': 'Toasted bread topped with fresh tomatoes, basil, and garlic.',
#   'ingredients': ['Bread', 'Tomatoes', 'Basil', 'Garlic'],
#   'cost': '$6.50',
#   'preparation_time': '10 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Starters',
#   'item_name': 'Chicken Caesar Salad',
#   'descriptiom': 'Crisp romaine lettuce topped with grilled chicken, croutons, and Caesar dressing.',
#   'ingredients': ['Romaine lettuce', 'Chicken', 'Croutons', 'Caesar dressing'],
#   'cost': '$9.99',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Starters',
#   'item_name': 'Beef Sliders',
#   'descriptiom': 'Mini beef burgers topped with cheese, lettuce, and tomato, served on brioche buns.',
#   'ingredients': ['Beef patties',
#    'Cheese',
#    'Lettuce',
#    'Tomato',
#    'Brioche buns'],
#   'cost': '$10.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Starters',
#   'item_name': 'Stuffed Mushrooms',
#   'descriptiom': 'Mushroom caps filled with a savory mix of cheese and herbs.',
#   'ingredients': ['Mushroom caps', 'Cheese', 'Breadcrumbs', 'Herbs'],
#   'cost': '$7.99',
#   'preparation_time': '18 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Main Course',
#   'item_name': 'Lamb Shank',
#   'descriptiom': 'Slow-cooked lamb shank in a rich red wine sauce with root vegetables.',
#   'ingredients': ['Lamb shank', 'Red wine', 'Root vegetables', 'Spices'],
#   'cost': '$21.99',
#   'preparation_time': '120 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Main Course',
#   'item_name': 'Teriyaki Salmon',
#   'descriptiom': 'Salmon fillets glazed with homemade teriyaki sauce and served with steamed rice.',
#   'ingredients': ['Salmon', 'Teriyaki sauce', 'Rice', 'Sesame seeds'],
#   'cost': '$16.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Main Course',
#   'item_name': 'Ribeye Steak',
#   'descriptiom': 'Grilled ribeye steak served with a side of mashed potatoes and steamed asparagus.',
#   'ingredients': ['Ribeye steak', 'Potatoes', 'Asparagus', 'Butter'],
#   'cost': '$24.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Main Course',
#   'item_name': 'Fettuccine Alfredo',
#   'descriptiom': 'Classic fettuccine pasta in a creamy Alfredo sauce with a hint of garlic.',
#   'ingredients': ['Fettuccine pasta', 'Cream', 'Parmesan cheese', 'Garlic'],
#   'cost': '$13.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Main Course',
#   'item_name': 'Grilled Chicken Caesar Wrap',
#   'descriptiom': 'Grilled chicken with Caesar salad wrapped in a soft tortilla.',
#   'ingredients': ['Chicken', 'Romaine lettuce', 'Caesar dressing', 'Tortilla'],
#   'cost': '$11.99',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Desserts',
#   'item_name': 'Crème Brûlée',
#   'descriptiom': 'Rich custard base topped with a contrasting layer of hard caramel.',
#   'ingredients': ['Cream', 'Vanilla', 'Eggs', 'Sugar'],
#   'cost': '$7.99',
#   'preparation_time': '45 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Desserts',
#   'item_name': 'Chocolate Fondue',
#   'descriptiom': 'Melted chocolate served with an assortment of fruits and marshmallows for dipping.',
#   'ingredients': ['Chocolate', 'Assorted fruits', 'Marshmallows'],
#   'cost': '$8.99',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Desserts',
#   'item_name': 'Panna Cotta',
#   'descriptiom': 'Silky smooth Italian dessert topped with a berry coulis.',
#   'ingredients': ['Cream', 'Gelatin', 'Sugar', 'Berry coulis'],
#   'cost': '$6.99',
#   'preparation_time': '240 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Desserts',
#   'item_name': 'Banana Split',
#   'descriptiom': 'Classic banana split with scoops of vanilla, chocolate, and strawberry ice cream, topped with sauces, whipped cream, and a cherry.',
#   'ingredients': ['Banana', 'Ice cream', 'Sauces', 'Whipped cream', 'Cherry'],
#   'cost': '$5.99',
#   'preparation_time': '10 minutes'},
#  {'restaurantname': 'Bistro Fusion',
#   'item_type': 'Desserts',
#   'item_name': 'Baklava',
#   'descriptiom': 'Sweet dessert pastry made of layers of filo filled with chopped nuts and sweetened with syrup.',
#   'ingredients': ['Filo pastry', 'Nuts', 'Honey', 'Butter'],
#   'cost': '$6.50',
#   'preparation_time': '50 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Starters',
#   'item_name': 'Paneer Tikka',
#   'descriptiom': 'Cubed paneer marinated in spices and grilled to perfection.',
#   'ingredients': ['Paneer', 'Yogurt', 'Spices'],
#   'cost': '$8.50',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Starters',
#   'item_name': 'Fish Amritsari',
#   'descriptiom': 'Fried fish fritters seasoned with carom seeds and gram flour.',
#   'ingredients': ['Fish', 'Carom seeds', 'Gram flour'],
#   'cost': '$9.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Starters',
#   'item_name': 'Mutton Kebabs',
#   'descriptiom': 'Minced mutton mixed with spices and grilled on skewers.',
#   'ingredients': ['Mutton', 'Spices', 'Mint'],
#   'cost': '$10.99',
#   'preparation_time': '30 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Starters',
#   'item_name': 'Chili Chicken',
#   'descriptiom': 'Crispy chicken tossed with bell peppers and onions in a spicy sauce.',
#   'ingredients': ['Chicken', 'Bell peppers', 'Onions', 'Soy sauce'],
#   'cost': '$9.50',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Starters',
#   'item_name': 'Vegetable Pakora',
#   'descriptiom': 'Assorted vegetables dipped in chickpea batter and fried to a golden crisp.',
#   'ingredients': ['Mixed vegetables', 'Chickpea flour', 'Spices'],
#   'cost': '$6.99',
#   'preparation_time': '15 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Main Course',
#   'item_name': 'Butter Paneer Masala',
#   'descriptiom': 'Paneer cubes simmered in a creamy tomato sauce and flavored with fenugreek.',
#   'ingredients': ['Paneer', 'Tomato sauce', 'Cream', 'Fenugreek'],
#   'cost': '$12.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Main Course',
#   'item_name': 'Chicken Biryani',
#   'descriptiom': 'Aromatic basmati rice cooked with chicken and a blend of spices.',
#   'ingredients': ['Chicken', 'Basmati rice', 'Spices', 'Saffron'],
#   'cost': '$14.99',
#   'preparation_time': '40 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Main Course',
#   'item_name': 'Lamb Vindaloo',
#   'descriptiom': 'A hot and tangy Goan dish made with lamb cooked in a vinegar-based sauce.',
#   'ingredients': ['Lamb', 'Vinegar', 'Garlic', 'Spices'],
#   'cost': '$16.99',
#   'preparation_time': '30 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Main Course',
#   'item_name': 'Fish Curry',
#   'descriptiom': 'Fish fillets cooked in a traditional curry sauce with tomatoes and tamarind.',
#   'ingredients': ['Fish', 'Tomatoes', 'Tamarind', 'Spices'],
#   'cost': '$15.99',
#   'preparation_time': '25 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Main Course',
#   'item_name': 'Chana Masala',
#   'descriptiom': 'Chickpeas cooked in a spicy tomato gravy with onions and herbs.',
#   'ingredients': ['Chickpeas', 'Tomato gravy', 'Onions', 'Herbs'],
#   'cost': '$10.99',
#   'preparation_time': '20 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Desserts',
#   'item_name': 'Gulab Jamun',
#   'descriptiom': 'Soft milk-based balls soaked in a warm sweet syrup.',
#   'ingredients': ['Milk solids', 'Flour', 'Sugar syrup', 'Cardamom'],
#   'cost': '$5.99',
#   'preparation_time': '30 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Desserts',
#   'item_name': 'Rasmalai',
#   'descriptiom': 'Chilled creamy dessert with paneer patties immersed in sweetened milk.',
#   'ingredients': ['Paneer', 'Milk', 'Sugar', 'Saffron'],
#   'cost': '$6.50',
#   'preparation_time': '45 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Desserts',
#   'item_name': 'Kulfi',
#   'descriptiom': 'Traditional Indian ice cream with nuts and cardamom.',
#   'ingredients': ['Milk', 'Sugar', 'Nuts', 'Cardamom'],
#   'cost': '$4.50',
#   'preparation_time': '360 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Desserts',
#   'item_name': 'Carrot Halwa',
#   'descriptiom': 'Warm pudding made with grated carrots, milk, nuts, and flavored with cardamom.',
#   'ingredients': ['Carrots', 'Milk', 'Nuts', 'Cardamom'],
#   'cost': '$5.50',
#   'preparation_time': '60 minutes'},
#  {'restaurantname': 'Spice Symphony',
#   'item_type': 'Desserts',
#   'item_name': 'Mango Lassi',
#   'descriptiom': 'A sweet and refreshing yogurt-based mango drink.',
#   'ingredients': ['Yogurt', 'Mango', 'Sugar', 'Cardamom'],
#   'cost': '$3.99',
#   'preparation_time': '5 minutes'}]

# %%
data = pd.DataFrame(details)
data.head(20)
# Out:
#         restaurantname    item_type                         item_name  \
# 0   The Culinary Haven     Starters                  Golden Corn Soup
# 1   The Culinary Haven     Starters             Chicken Satay Skewers
# 2   The Culinary Haven     Starters                    Beef Carpaccio
# 3   The Culinary Haven     Starters             Crispy Calamari Rings
# 4   The Culinary Haven     Starters               Veggie Spring Rolls
# 5   The Culinary Haven  Main Course                 Mutton Rogan Josh
# 6   The Culinary Haven  Main Course    Grilled Salmon with Dill Sauce
# 7   The Culinary Haven  Main Course  Beef Steak with Peppercorn Sauce
# 8   The Culinary Haven  Main Course                 Vegetable Lasagna
# 9   The Culinary Haven  Main Course                    Butter Chicken
# 10  The Culinary Haven     Desserts               Chocolate Lava Cake
# 11  The Culinary Haven     Desserts               New York Cheesecake
# 12  The Culinary Haven     Desserts                          Tiramisu
# 13  The Culinary Haven     Desserts               Apple Pie a la Mode
# 14  The Culinary Haven     Desserts                      Lemon Sorbet
# 15       Bistro Fusion     Starters                   Shrimp Cocktail
# 16       Bistro Fusion     Starters            Bruschetta al Pomodoro
# 17       Bistro Fusion     Starters              Chicken Caesar Salad
# 18       Bistro Fusion     Starters                      Beef Sliders
# 19       Bistro Fusion     Starters                 Stuffed Mushrooms
#
#                                           descriptiom  \
# 0   A creamy, comforting blend of sweet corn and h...
# 1   Grilled chicken skewers marinated in a blend o...
# 2   Thinly sliced raw beef dressed with olive oil,...
# 3   Fried calamari rings served with a tangy marin...
# 4   Crispy rolls filled with fresh vegetables and ...
# 5   A classic Kashmiri dish with tender mutton pie...
# 6   Fresh salmon fillets grilled to perfection, to...
# 7   Juicy beef steak cooked to your preference and...
# 8   Layers of pasta, rich tomato sauce, and roaste...
# 9   Tender chicken pieces in a creamy tomato gravy...
# 10  A warm, gooey chocolate cake with a molten cen...
# 11  Creamy cheesecake with a graham cracker crust ...
# 12  A classic Italian no-bake dessert with layers ...
# 13  Traditional apple pie served warm with a scoop...
# 14  A refreshing and tangy frozen dessert made wit...
# 15  Chilled shrimp served with a zesty cocktail sa...
# 16  Toasted bread topped with fresh tomatoes, basi...
# 17  Crisp romaine lettuce topped with grilled chic...
# 18  Mini beef burgers topped with cheese, lettuce,...
# 19  Mushroom caps filled with a savory mix of chee...
#
#                                           ingredients    cost preparation_time
# 0         [Sweet corn, Vegetable stock, Cream, Herbs]   $5.99       10 minutes
# 1          [Chicken, Soy sauce, Peanut sauce, Spices]   $7.99       15 minutes
# 2              [Beef, Olive oil, Lemon juice, Capers]   $9.99       10 minutes
# 3            [Calamari, Flour, Marinara sauce, Lemon]   $8.50       12 minutes
# 4   [Cabbage, Carrot, Glass noodles, Spring roll w...   $6.50       15 minutes
# 5              [Mutton, Yogurt, Spices, Tomato puree]  $15.99       30 minutes
# 6                        [Salmon, Dill, Lemon, Cream]  $17.99       25 minutes
# 7            [Beef steak, Peppercorns, Cream, Butter]  $19.99       20 minutes
# 8   [Pasta sheets, Tomato sauce, Mixed vegetables,...  $12.99       35 minutes
# 9       [Chicken, Tomato puree, Cream, Indian spices]  $14.99       25 minutes
# 10                    [Chocolate, Flour, Eggs, Sugar]   $6.99       20 minutes
# 11  [Cream cheese, Graham crackers, Eggs, Berry co...   $7.50       60 minutes
# 12  [Ladyfingers, Coffee, Mascarpone cheese, Cocoa...   $7.99       30 minutes
# 13   [Apples, Pie crust, Cinnamon, Vanilla ice cream]   $5.99       45 minutes
# 14                             [Lemons, Sugar, Water]   $4.99      180 minutes
# 15                    [Shrimp, Cocktail sauce, Lemon]   $8.99       10 minutes
# 16                   [Bread, Tomatoes, Basil, Garlic]   $6.50       10 minutes
# 17  [Romaine lettuce, Chicken, Croutons, Caesar dr...   $9.99       15 minutes
# 18  [Beef patties, Cheese, Lettuce, Tomato, Brioch...  $10.99       20 minutes
# 19        [Mushroom caps, Cheese, Breadcrumbs, Herbs]   $7.99       18 minutes

# %%
data["cost"] = data["cost"].str.replace("$", "").str.strip().apply(float)

# %%
data["preparation_time"] = data["preparation_time"].str.replace("minutes", "").str.strip().apply(int)

# %%
data["ingredients"] = data["ingredients"].apply(", ".join)

# %%
data.to_csv("data/restaurant_details_openai.csv", index=False)

# %%
data["item_type"].unique()
# Out:
# array(['Starters', 'Main Course', 'Desserts'], dtype=object)

# %%
restaurant_names = dict((name, idx)for idx, name in enumerate(data["restaurantname"].unique()))
restaurant_names
# Out:
# {'The Culinary Haven': 0, 'Bistro Fusion': 1, 'Spice Symphony': 2}

# %%
restaurant_names_df = pd.DataFrame({"id": restaurant_names.values(), "names": restaurant_names.keys()})
restaurant_names_df.to_csv("data/restaurant_names.csv", index=False)

# %%
data["restaurantname"] = data["restaurantname"].map(restaurant_names)

# %%
data.head(5)
# Out:
#    restaurantname item_type              item_name  \
# 0               0  Starters       Golden Corn Soup
# 1               0  Starters  Chicken Satay Skewers
# 2               0  Starters         Beef Carpaccio
# 3               0  Starters  Crispy Calamari Rings
# 4               0  Starters    Veggie Spring Rolls
#
#                                          descriptiom  \
# 0  A creamy, comforting blend of sweet corn and h...
# 1  Grilled chicken skewers marinated in a blend o...
# 2  Thinly sliced raw beef dressed with olive oil,...
# 3  Fried calamari rings served with a tangy marin...
# 4  Crispy rolls filled with fresh vegetables and ...
#
#                                          ingredients  cost  preparation_time
# 0          Sweet corn, Vegetable stock, Cream, Herbs  5.99                10
# 1           Chicken, Soy sauce, Peanut sauce, Spices  7.99                15
# 2               Beef, Olive oil, Lemon juice, Capers  9.99                10
# 3             Calamari, Flour, Marinara sauce, Lemon  8.50                12
# 4  Cabbage, Carrot, Glass noodles, Spring roll wr...  6.50                15

# %%
data

# %%
data.to_csv("data/restaurant_details.csv", index=False)
